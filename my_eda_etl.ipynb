# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *
from psycopg2.errors import UniqueViolation
import json
import datetime
import re
import sql_queries

# %%
conn.close()

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
cur.execute(sql_queries.song_table_create)

# %%
conn.commit()

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('./data/song_data')

# %%
len(song_files)
# Out:
# 71

# %%
log_files = get_files('./data/log_data/2018/11')

# %%
len(log_files)
# Out:
# 30

# %%
log_files[0]
# Out:
# '/Users/markbrennan/udacity/projects/data_modeling_with_postgres/data/log_data/2018/11/2018-11-11-events.json'

# %%
df_songs = pd.read_json(song_files[0], lines=True)
df_songs.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  AR7G5I41187FB4CE6C              NaN  London, England               NaN
#
#   artist_name   duration  num_songs             song_id            title  year
# 0    Adam Ant  233.40363          1  SONHOTT12A8C13493C  Something Girls  1982

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = 
song_data

# %%
df_songs.values[0][0]
# Out:
# 'AR7G5I41187FB4CE6C'

# %%
df_songs.artist_id
# Out:
# 0    AR7G5I41187FB4CE6C
# Name: artist_id, dtype: object

# %%
idx=0

# %%
song_data = (df_songs.song_id[idx], 
             df_songs.title[idx], 
             df_songs.artist_id[idx], 
             int(df_songs.year[idx]), 
             float(df_songs.duration[idx]))

# %%
song_table_insert = """
INSERT INTO songs(song_id, title, artist_id, year, duration)
VALUES (%s, %s, %s, %s, %s)
"""

# %%
for file in song_files_test:
    df_songs = pd.read_json(file, lines=True)
    for idx, row in df_songs.iterrows():
        song_data = (row.song_id, 
                     row.title, 
                     row.artist_id, 
                     int(row.year), 
                     float(row.duration))
        print(f'inserting {song_data}')
        try:
            cur.execute(song_table_insert, song_data)
        except UniqueViolation as e:
                print('caught UniqueViolation exception!')
                print(e.pgerror)
                print(e.diag.message_primary)
                continue
# Out:
# inserting ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363)
# inserting ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832)

# %% [markdown]
# ## READ AND INSERT SONG DATA

# %%
def read_and_insert_song_data(song_files):
    song_table_insert = """
    INSERT INTO songs(song_id, title, artist_id, year, duration)
    VALUES (%s, %s, %s, %s, %s)
    """    
    for file in song_files:
        with open(file) as f:
            try:
                data = json.load(f)
                song_data = (data['song_id'], 
                             data['title'],
                             data['artist_id'],
                             data['year'],
                             data['duration'])
                print(f'inserting {song_data}')

                cur.execute(song_table_insert, song_data)
            except psycopg2.Error as e:
                    print('caught psycopg2 exception!')
                    print(e.pgerror)
                    print(e.diag.message_primary)
                    continue
            except KeyError as e:
                print(f'Key Error:  {str(e)}')
                continue   
            except JSONDecodeError as e:
                print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
                continue   
    conn.commit()

# %%
def get_song_and_artist_data(song_files):
    song_data = []
    artist_data = []
    for file in song_files:
        with open(file) as f:
            try:
                data = json.load(f)
                song_data.append(dict(song_id=data['song_id'],
                                      title=data['title'],
                                      artist_id=data['artist_id'],
                                      year=data['year'],
                                      duration=data['duration']))
                artist_data.append(dict(artist_id=data['artist_id'],
                                        artist_name=data['artist_name'],
                                        artist_location=data['artist_location'],
                                        artist_latitude=data['artist_latitude'],
                                        artist_longitude=data['artist_longitude']))

            except KeyError as e:
                print(f'Key Error:  {str(e)}')
                continue   
            except JSONDecodeError as e:
                print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
                continue
    return song_data, artist_data

# %%
song_data, artist_data = get_song_and_artist_data(song_files)

# %%
def insert_song_data(song_data):
    song_table_insert = """
                        INSERT INTO songs(song_id, title, artist_id, year, duration)
                        VALUES (%s, %s, %s, %s, %s)
                        """    
    for song in song_data:
        try:
            song_data = (song['song_id'], 
                         song['title'],
                         song['artist_id'],
                         song['year'],
                         song['duration'])
            print(f'inserting {song_data}')
            cur.execute(song_table_insert, song_data)
        except psycopg2.Error as e:
            print('caught psycopg2 exception!')
            print(e.pgerror)
            print(e.diag.message_primary)
            continue
        except KeyError as e:
            print(f'Key Error:  {str(e)}')
            continue   
            
    conn.commit()

# %%
insert_song_data(song_data)
# Out:
# inserting ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363)
# inserting ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832)
# inserting ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 209.60608)
# inserting ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 189.57016)
# inserting ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 218.77506)
# inserting ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148.03546)
# inserting ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179)
# inserting ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177.47546)
# inserting ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628)
# inserting ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 267.7024)
# inserting ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 114.78159)
# inserting ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156.39465)
# inserting ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 342.56934)
# inserting ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133.32853)
# inserting ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 124.86485)
# inserting ('SOZQDIU12A58A7BCF6', 'Superconfidential', 'ARNTLGG11E2835DDB9', 0, 338.31138)
# inserting ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 173.66159)
# inserting ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751)
# inserting ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 164.80608)
# inserting ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225.09669)
# inserting ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, 186.48771)
# inserting ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, 313.12934)
# inserting ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 269.58322)
# inserting ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 484.62322)
# inserting ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168.25424)
# inserting ('SOMUYGI12AB0188633', 'La Culpa', 'ARL7K851187B99ACD2', 0, 226.35057)
# inserting ('SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, 165.69424)
# inserting ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, 151.84934)
# inserting ('SOUQQEA12A8C134B1B', 'High Tide', 'ARIG6O41187B988BDD', 0, 228.5971)
# inserting ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 191.84281)
# inserting ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 'ARC43071187B990240', 0, 245.21098)
# inserting ('SOBEBDG12A58A76D60', 'Kassie Jones', 'ARI3BMM1187FB4255E', 0, 220.78649)
# inserting ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, 307.3824)
# inserting ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, 491.12771)
# inserting ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 'AR1ZHYZ1187FB3C717', 0, 599.24853)
# inserting ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290.29832)
# inserting ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 'ARMBR4Y1187B9990EB', 0, 241.47546)
# inserting ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 236.93016)
# inserting ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 'ARQ9BO41187FB5CF1F', 0, 183.17016)
# inserting ('SOPVXLX12A8C1402D5', 'Larger Than Life', 'AR3JMC51187B9AE49D', 1999, 236.25098)
# inserting ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 'AREDBBQ1187B98AFF5', 0, 138.63138)
# inserting ('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'ARPBNLO1187FB3D52F', 2000, 43.36281)
# inserting ('SOQVMXR12A81C21483', 'Salt In NYC', 'ARKULSX1187FB45F84', 0, 424.12363)
# inserting ('SOSLAVG12A8C13397F', 'Den Pai Alo', 'AROGWRA122988FEE45', 0, 243.82649)
# inserting ('SODUJBS12A8C132150', 'Wessex Loses a Bride', 'ARI2JSK1187FB496EF', 0, 111.62077)
# inserting ('SOQLGFP12A58A7800E', 'OAKtown', 'ARD7TVE1187B99BFB1', 0, 259.44771)
# inserting ('SOTUKVB12AB0181477', 'Blessed Assurance', 'AR7ZKHQ1187B98DD73', 1993, 270.602)
# inserting ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326.00771)
# inserting ('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 335.51628)
# inserting ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, 279.97995)
# inserting ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, 152.92036)
# inserting ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, 197.19791)
# inserting ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 290.55955)
# inserting ('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.86404)
# inserting ('SODAUVL12A8C13D184', 'Prognosis', 'ARWB3G61187FB49404', 2000, 363.85914)
# inserting ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 261.51138)
# inserting ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282.43546)
# inserting ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305.162)
# inserting ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 75.67628)
# inserting ('SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 'AR36F9J1187FB406F1', 0, 230.71302)
# inserting ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 'AR7SMBG1187B9B9066', 0, 218.38322)
# inserting ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 'ARDR4AC1187FB371A1', 0, 511.16363)
# inserting ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, 173.19138)
# inserting ('SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 'AREDL271187FB40F44', 0, 45.66159)
# inserting ('SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 'ARP6N5A1187B99D1A3', 2004, 207.43791)
# inserting ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 'ARGSAFR1269FB35070', 0, 29.54404)
# inserting ('SOLEYHO12AB0188A85', 'Got My Mojo Workin', 'ARAGB2O1187FB3A161', 0, 338.23302)
# inserting ('SOGVQGJ12AB017F169', 'Ten Tonne', 'AR62SOJ1187FB47BB5', 2005, 337.68444)
# inserting ('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 'ARBEBBY1187B9B43DB', 1994, 236.17261)
# inserting ('SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 'ARNNKDK1187B98BBD5', 0, 407.37914)
# inserting ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153.33832)

# %%
def insert_artist_data(artist_data):
    artist_table_insert = """INSERT INTO artists(artist_id, name, location, latitude, longitude) 
                                VALUES(%s, %s, %s, %s, %s)"""
    artists_seen = set()    
    for artist in artist_data:
        artist_id = artist['artist_id']
        if artist_id and artist_id not in artists_seen:
            artists_seen.add(artist_id)
            artist_data = (artist_id, 
                           artist['artist_name'],
                           artist['artist_location'],
                           artist['artist_latitude'],
                           artist['artist_longitude'])
            print(f'inserting {artist_data}')
            try:
                cur.execute(artist_table_insert, artist_data)
            except psycopg2.Error as e:
                    print('caught psycopg2 exception!')
                    print(e.pgerror)
                    print(e.diag.message_primary)
                    continue
    conn.commit()

# %%
insert_artist_data(artist_data)
# Out:
# inserting ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', None, None)
# inserting ('AR8ZCNI1187B9A069B', 'Planet P Project', '', None, None)
# inserting ('ARXR32B1187FB57099', 'Gob', '', None, None)
# inserting ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', None, None)
# inserting ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955)
# inserting ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892)
# inserting ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None)
# inserting ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', None, None)
# inserting ('ARNTLGG11E2835DDB9', 'Clp', '', None, None)
# inserting ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', None, None)
# inserting ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None)
# inserting ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418)
# inserting ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241)
# inserting ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158)
# inserting ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868)
# inserting ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', None, None)
# inserting ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995)
# inserting ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168)
# inserting ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', None, None)
# inserting ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', 32.67828, -83.22295)
# inserting ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', None, None)
# inserting ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491)
# inserting ('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', 27.94017, -82.32547)
# inserting ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512)
# inserting ('ARL7K851187B99ACD2', 'Andy Andy', '', None, None)
# inserting ('ARNPAGP1241B9C7FD4', 'lextrical', '', None, None)
# inserting ('ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', 34.31109, -94.02978)
# inserting ('ARIG6O41187B988BDD', 'Richard Souther', 'United States', 37.16793, -95.84502)
# inserting ('ARHHO3O1187B989413', 'Bob Azzam', '', None, None)
# inserting ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', None, None)
# inserting ('ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', 38.8991, -77.029)
# inserting ('ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', None, None)
# inserting ('ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', 43.64856, -79.38533)
# inserting ('AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', None, None)
# inserting ('ARYKCQI1187FB3B18F', 'Tesla', '', None, None)
# inserting ('ARMBR4Y1187B9990EB', 'David Martin', 'California - SF', 37.77916, -122.42005)
# inserting ('AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', None, None)
# inserting ('ARQ9BO41187FB5CF1F', 'John Davis', 'Pennsylvania', 40.99471, -77.60454)
# inserting ('AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', 28.53823, -81.37739)
# inserting ('AREDBBQ1187B98AFF5', 'Eddie Calvert', '', None, None)
# inserting ('ARPBNLO1187FB3D52F', 'Tiny Tim', 'New York, NY', 40.71455, -74.00712)
# inserting ('ARKULSX1187FB45F84', 'Trafik', 'Utah', 39.49974, -111.54732)
# inserting ('AROGWRA122988FEE45', 'Christos Dantis', '', None, None)
# inserting ('ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright', 'London, England', 51.50632, -0.12714)
# inserting ('AR7ZKHQ1187B98DD73', 'Glad', '', None, None)
# inserting ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925)
# inserting ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', None, None)
# inserting ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', 41.88415, -87.63241)
# inserting ('ARJIE2Y1187B994AB7', 'Line Renaud', '', None, None)
# inserting ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', 8.4177, -80.11278)
# inserting ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', None, None)
# inserting ('AR8IEZO1187B99055E', 'Marc Shaiman', '', None, None)
# inserting ('ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', None, None)
# inserting ('AR051KA1187B98B2FF', 'Wilks', '', None, None)
# inserting ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13.442, -41.9952)
# inserting ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644)
# inserting ('AR558FS1187FB45658', '40 Grit', '', None, None)
# inserting ('AR36F9J1187FB406F1', 'Bombay Rockers', 'Denmark', 56.27609, 9.51695)
# inserting ('AR7SMBG1187B9B9066', 'Los Manolos', '', None, None)
# inserting ('ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', None, None)
# inserting ('ARBGXIG122988F409D', 'Steel Rain', 'California - SF', 37.77916, -122.42005)
# inserting ('AREDL271187FB40F44', 'Soul Mekanik', '', None, None)
# inserting ('ARP6N5A1187B99D1A3', 'Mitch Ryder', 'Hamtramck, MI', None, None)
# inserting ('ARGSAFR1269FB35070', 'Blingtones', '', None, None)
# inserting ('ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers', '', None, None)
# inserting ('AR62SOJ1187FB47BB5', 'Chase & Status', '', None, None)
# inserting ('ARBEBBY1187B9B43DB', 'Tom Petty', 'Gainesville, FL', None, None)
# inserting ('ARNNKDK1187B98BBD5', 'Jinx', 'Zagreb Croatia', 45.80726, 15.9676)
# inserting ('ARGCY1Y1187B9A4FA5', 'Gloriana', 'Nashville, TN.', 36.16778, -86.77836)

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('./data/log_data/2018/11')

# %%
log_files[0]
# Out:
# '/Users/markbrennan/udacity/projects/data_modeling_with_postgres/data/log_data/2018/11/2018-11-11-events.json'

# %%
len(log_files)
# Out:
# 30

# %%
filepath =

# %%
df_log = pd.read_json(log_files[0], lines=True)
df_log.head(1)
# Out:
#      artist       auth firstName gender  itemInSession lastName     length  \
# 0  Frumpies  Logged In  Anabelle      F              0  Simpson  134.47791
#
#   level                                     location method      page  \
# 0  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD    PUT  NextSong
#
#    registration  sessionId        song  status             ts  \
# 0  1.541044e+12        455  Fuck Kitty     200  1541903636796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     69

# %%
#timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and

# %%
# user_id', 'first', 'last', 'gender','level'

# %% [markdown]
# ## DO THE MAIN WORK OF READING LOG/EVENT DATA

# %%
def get_all_log_data(log_files):
    all_log_data = []
    for file in log_files:
        with open(file, 'r') as f:
            for line in f:
                try:
                    data = json.loads(line)
                except JSONDecodeError as e:
                    print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
                    continue
                    
                if data['page'] == 'NextSong':
                    try:
                        all_log_data.append(dict(ts=data['ts'],
                                                 user_id=data['userId'],
                                                 first_name=data['firstName'],
                                                 last_name=data['lastName'],
                                                 gender=data['gender'],
                                                 level=data['level'],
                                                 song_title=data['song'],
                                                 artist_name=data['artist'],
                                                 length=data['length'],
                                                 session_id=data['sessionId'],
                                                 location=data['location'],
                                                 user_agent=data['userAgent']
                                                ))
                    except KeyError as e:
                        print(f'Key Error:  {str(e)}')
                        continue
    return all_log_data

# %%
all_log_data = get_all_log_data(log_files)

# %%
all_log_data[0]
# Out:
# {'ts': 1541903636796,
#  'user_id': '69',
#  'first_name': 'Anabelle',
#  'last_name': 'Simpson',
#  'gender': 'F',
#  'level': 'free',
#  'song_title': 'Fuck Kitty',
#  'artist_name': 'Frumpies',
#  'length': 134.47791,
#  'session_id': 455,
#  'location': 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#  'user_agent': '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'}

# %%
len(all_log_data)
# Out:
# 6820

# %% [markdown]
# ## TIME DATA

# %%
INSERT_TIME_QUERY = """INSERT INTO time(timestamp, hour, day, week, month, year, weekday) 
                    VALUES (%s, %s, %s, %s, %s, %s, %s)"""

# %%
def get_timestamp(ts):
    dt = datetime.datetime.fromtimestamp(ts / 1000)
    return dt, dt.strftime('%Y-%m-%d %H:%M:%S.%f')

# %%
def insert_time_data(all_log_data, time_query):
    seen_timestamps = set()
    for entry in all_log_data:
        ts = None
        try:
            ts = entry['ts']
        except KeyError as e:
            print(f'Key Error:  {str(e)}')
            continue
        if ts and ts not in seen_timestamps:
            seen_timestamps.add(ts)
            dt, timestamp = get_timestamp(ts)
            hour = dt.hour
            day = dt.day
            year, week, weekday = dt.isocalendar()
            month = dt.month
            insert_vals = (timestamp, hour, day, week, month, year, weekday)
            try:
                cur.execute(time_query, insert_vals)
            except psycopg2.Error as e:
                    print('caught psycopg2 exception!')
                    print(e.pgerror)
                    print(e.diag.message_primary)
                    continue
    conn.commit()

# %%
insert_time_data(all_log_data, INSERT_TIME_QUERY)

# %% [markdown]
# ## USER DATA

# %%
INSERT_USER_QUERY = """INSERT INTO users(user_id, first_name, last_name, gender, level) 
                        VALUES (%s, %s, %s, %s, %s)"""

# %%
def insert_user_data(all_log_data, insert_user_query):
    seen_users = set()
    for entry in all_log_data:
        user_id = first_name = last_name = gender = level = None
        try:
            user_id = entry['user_id']
            first_name = entry['first_name']
            last_name = entry['last_name']
            gender = entry['gender']
            level = entry['level']
        except KeyError as e:
            print(f'Key Error:  {str(e)}')
            continue
        if user_id and user_id not in seen_users and first_name and last_name and gender and level: 
            seen_users.add(user_id)
            insert_vals = (user_id, first_name, last_name, gender, level)
            try:
                cur.execute(insert_user_query, insert_vals)
            except psycopg2.Error as e:
                    print('caught psycopg2 exception!')
                    print(e.pgerror)
                    print(e.diag.message_primary)
                    continue    
    conn.commit()

# %%
insert_user_data(all_log_data, INSERT_USER_QUERY)

# %% [markdown]
# ## SONG PLAYS DATA

# %%
SONG_ARTIST_ID_QRY = "SELECT song_id, s.artist_id \
FROM songs s JOIN artists a on s.artist_id = a.artist_id \
WHERE title = '{}' and a.name='{}' and duration={}"

# %%
SONG_ARTIST_ID_QRY
# Out:
# "SELECT song_id, s.artist_id FROM songs s JOIN artists a on s.artist_id = a.artist_id WHERE title = '{}' and a.name='{}' and duration={}"

# %%
SONG_ARTIST_ID_QRY.format(title,name,duration)
# Out:
# "SELECT song_id, s.artist_id FROM songs s JOIN artists a on s.artist_id = a.artist_id WHERE title = 'Setanta matins' and a.name='Elena' and duration=269.58322"

# %% [markdown]
# Implement the song_select query in sql_queries.py to find the song ID and artist ID based on the title, artist name, and duration of a song.
# Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to songplay_data

# %%
df_log.head(1)
# Out:
#                 artist       auth firstName gender  itemInSession  lastName  \
# 0  Great Lake Swimmers  Logged In     Kevin      M              0  Arellano
#
#       length level                 location method      page  registration  \
# 0  215.11791  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
#
#    sessionId              song  status             ts  \
# 0        815  Your Rocky Spine     200  1542931645796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66

# %%
all_log_data[0]
# Out:
# {'ts': 1541903636796,
#  'user_id': '69',
#  'first_name': 'Anabelle',
#  'last_name': 'Simpson',
#  'gender': 'F',
#  'level': 'free',
#  'song_title': 'Fuck Kitty',
#  'artist_name': 'Frumpies',
#  'length': 134.47791,
#  'session_id': 455,
#  'location': 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#  'user_agent': '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'}

# %%
#songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent

# %%
def insert_song_play_data(all_log_data):
    song_artist_id_qry = "SELECT song_id, s.artist_id \
                            FROM songs s JOIN artists a on s.artist_id = a.artist_id \
                            WHERE title = '{}' and a.name = '{}' and duration = {}"
    insert_query = """INSERT INTO songplays(start_time, user_id, level, song_id, artist_id, session_id, location, user_agent) 
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    for entry in all_log_data:
        # find the song ID and artist ID based on the title, artist name, and duration of a song.
        #  timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent 
        song_title = artist_name = duration = None
        song_title = entry['song_title'] 
        artist_name = entry['artist_name']
        duration = entry['length']
        if song_title and artist_name and duration:
            # escape apostrophes in song titles
            song_title = re.sub("'", "''", song_title)
            # and escape apostrophes in artist names
            artist_name = re.sub("'", "''", artist_name)            
            query = song_artist_id_qry.format(song_title, artist_name, duration)
            try:
                song_id = artist_id = None
                cur.execute(query)
                row = cur.fetchone()
                if row:
                    song_id, artist_id = row
                
                _, timestamp = get_timestamp(entry['ts'])
                user_id = entry['user_id']
                level = entry['level']
                session_id = entry['session_id']
                location = entry['location']
                user_agent = entry['user_agent']
                insert_vals = (timestamp, user_id, level, song_id, artist_id, 
                               session_id, location, duration)
                cur.execute(insert_query, insert_vals)

            except psycopg2.Error as e:
                print('caught psycopg2 exception!')
                print(e.pgerror)
                print(e.diag.message_primary)
                continue     
            except KeyError as e:
                print(f'Key Error:  {str(e)}')
                continue
        conn.commit()

# %%
insert_song_play_data(all_log_data)

# %%
qry = """SELECT song_id, s.artist_id                             FROM songs s JOIN artists a on s.artist_id = a.artist_id                             
        WHERE title = 'Setanta matins' and a.name = 'Elena' and duration = 269.58322"""

# %%
cur.execute(qry)

# %%
print(cur.fetchone())
# Out:
# None

# %%
if row:
    song_id, artist_id = row
    print(song_id, artist_id)
# Out:
# SOZCTXZ12AB0182364 AR5KOSW1187FB35FF4

# %% [markdown]
# ## OLDER QUERIES - Keep as notes, but do not use

# %%
# #start_time, hour, day, week, month, year, weekday
# seen_timestamps = set()
# for file in log_files:
#     with open(file, 'r') as f:
#         for line in f:
#             d = json.loads(line)
#             ts = d['ts']
#             print(ts)
#             if ts not in seen_timestamps:
#                 seen_timestamps.add(ts)
#                 dt = datetime.fromtimestamp(ts / 1000)
#                 timestamp = dt.strftime('%Y-%m-%d %H:%M:%S.%f')
#                 hour = dt.hour
#                 day = dt.day
#                 year, week, weekday = dt.isocalendar()
#                 month = dt.month
#                 insert_vals = (timestamp, hour, day, week, month, year, weekday)
#                 print(f'insert_vals: {insert_vals}')
#                 try:
#                     cur.execute(time_query, insert_vals)
#                 except psycopg2.Error as e:
#                         print('caught psycopg2 exception!')
#                         print(e.pgerror)
#                         print(e.diag.message_primary)
#                         continue
# Out:
# 1541903636796
# insert_vals: ('2018-11-10 21:33:56.796000', 21, 10, 45, 11, 2018, 6)
# 1541903770796
# insert_vals: ('2018-11-10 21:36:10.796000', 21, 10, 45, 11, 2018, 6)
# 1541904034796
# insert_vals: ('2018-11-10 21:40:34.796000', 21, 10, 45, 11, 2018, 6)
# 1541910841796
# 1543085103796
# insert_vals: ('2018-11-24 13:45:03.796000', 13, 24, 47, 11, 2018, 6)
# 1543085320796
# insert_vals: ('2018-11-24 13:48:40.796000', 13, 24, 47, 11, 2018, 6)
# 1543085542796
# insert_vals: ('2018-11-24 13:52:22.796000', 13, 24, 47, 11, 2018, 6)
# 1543085791796
# insert_vals: ('2018-11-24 13:56:31.796000', 13, 24, 47, 11, 2018, 6)
# 1543085795796
# insert_vals: ('2018-11-24 13:56:35.796000', 13, 24, 47, 11, 2018, 6)
# 1543085941796
# insert_vals: ('2018-11-24 13:59:01.796000', 13, 24, 47, 11, 2018, 6)
# 1543086055796
# insert_vals: ('2018-11-24 14:00:55.796000', 14, 24, 47, 11, 2018, 6)
# 1543086121796
# insert_vals: ('2018-11-24 14:02:01.796000', 14, 24, 47, 11, 2018, 6)
# 1543086185796
# insert_vals: ('2018-11-24 14:03:05.796000', 14, 24, 47, 11, 2018, 6)
# 1543086275796
# insert_vals: ('2018-11-24 14:04:35.796000', 14, 24, 47, 11, 2018, 6)
# 1543086384796
# insert_vals: ('2018-11-24 14:06:24.796000', 14, 24, 47, 11, 2018, 6)
# 1543086424796
# insert_vals: ('2018-11-24 14:07:04.796000', 14, 24, 47, 11, 2018, 6)
# 1543086642796
# insert_vals: ('2018-11-24 14:10:42.796000', 14, 24, 47, 11, 2018, 6)
# 1543092145796
# insert_vals: ('2018-11-24 15:42:25.796000', 15, 24, 47, 11, 2018, 6)
# 1543092353796
# insert_vals: ('2018-11-24 15:45:53.796000', 15, 24, 47, 11, 2018, 6)
# 1543092558796
# insert_vals: ('2018-11-24 15:49:18.796000', 15, 24, 47, 11, 2018, 6)
# 1543097750796
# insert_vals: ('2018-11-24 17:15:50.796000', 17, 24, 47, 11, 2018, 6)
# 1543097978796
# insert_vals: ('2018-11-24 17:19:38.796000', 17, 24, 47, 11, 2018, 6)
# 1543103174796
# insert_vals: ('2018-11-24 18:46:14.796000', 18, 24, 47, 11, 2018, 6)

# %%
# with open(log_files[0], 'r') as f:
#     for line in f:
#         d = json.loads(line)
#         print(d)
#         break

# %%
# from json import JSONDecodeError
# def read_log_data(log_files):
#     timestamps = []
#     users = []
#     for file in log_files:
#         with open(file, 'r') as f:
#             for line in f:
#                 try:
#                     d = json.loads(line)
#                 except JSONDecodeError as e:
#                     print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
#                     continue
                    
#                 if d['page'] == 'NextSong':
#                     timestamps.append(d['ts'])
#                     # user ID, first name, last name, gender and level
#                     users.append(dict(user_id=d['userId'],
#                                       first=d['firstName'],
#                                       last=d['lastName'],
#                                       gender=d['gender'],
#                                       level=d['level']))
#     return timestamps, users

# %%
# timestamps, users = read_log_data(log_files)

# %%
# def insert_time_data(timestamps):
#     seen_timestamps = set()
#     for ts in timestamps:
#         if ts not in seen_timestamps:
#             seen_timestamps.add(ts)
#             dt = datetime.fromtimestamp(ts / 1000)
#             timestamp = dt.strftime('%Y-%m-%d %H:%M:%S.%f')
#             hour = dt.hour
#             day = dt.day
#             year, week, weekday = dt.isocalendar()
#             month = dt.month
#             insert_vals = (timestamp, hour, day, week, month, year, weekday)
#             print(f'insert_vals: {insert_vals}')
#             try:
#                 cur.execute(time_query, insert_vals)
#             except psycopg2.Error as e:
#                     print('caught psycopg2 exception!')
#                     print(e.pgerror)
#                     print(e.diag.message_primary)
#                     continue

# %%
# def insert_user_data(users):
#     seen_users = set()
#     for user in users:
#         user_id = user['user_id']
#         if  user_id not in seen_users:
#             seen_users.add(user_id)
#             insert_vals = (user_id, 
#                            user['first'], 
#                            user['last'], 
#                            user['gender'], 
#                            user['level'])
#             try:
#                 cur.execute(user_insert_query, insert_vals)
#             except psycopg2.Error as e:
#                     print('caught psycopg2 exception!')
#                     print(e.pgerror)
#                     print(e.diag.message_primary)
#                     continue

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = 
df.head()

# %%
t = 
t.head()

# %%
time_data = ()
column_labels = ()

# %%
time_df = 
time_df.head()

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
df_log = pd.read_json(log_files[0], lines=True)
df_log.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0                   Frumpies  Logged In  Anabelle      F              0
# 1  Kenny G with Peabo Bryson  Logged In  Anabelle      F              1
# 2                Biffy Clyro  Logged In  Anabelle      F              2
# 3                       None  Logged In      Lily      F              0
# 4                        HIM  Logged In      Lily      F              1
#
#   lastName     length level                                     location  \
# 0  Simpson  134.47791  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 1  Simpson  264.75057  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 2  Simpson  189.83138  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 3    Burns        NaN  free        New York-Newark-Jersey City, NY-NJ-PA
# 4    Burns  212.06159  free        New York-Newark-Jersey City, NY-NJ-PA
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.541044e+12        455                      Fuck Kitty
# 1    PUT  NextSong  1.541044e+12        455  By The Time This Night Is Over
# 2    PUT  NextSong  1.541044e+12        455                     God & Satan
# 3    GET      Home  1.540621e+12        456                            None
# 4    PUT  NextSong  1.540621e+12        456                       Beautiful
#
#    status             ts                                          userAgent  \
# 0     200  1541903636796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1541903770796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1541904034796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3     200  1541910841796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4     200  1541910973796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
#
#   userId
# 0     69
# 1     69
# 2     69
# 3     32
# 4     32

# %%
user_df =

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    results = cur.execute(song_select, (row.song, row.artist, row.length))
    songid, artistid = results if results else None, None

    # insert songplay record
    songplay_data = ()
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %%
# songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent

# %%
df_log = pd.read_json(log_files[1], lines=True)

# %%
df_log
# Out:
#                                             artist        auth firstName  \
# 0                              Great Lake Swimmers   Logged In     Kevin
# 1                              Soziedad Alkoholika   Logged In     Kevin
# 2                                  Franz Ferdinand   Logged In     Kevin
# 3                                     Modest Mouse   Logged In     Kevin
# 4                                     Adam Lambert   Logged In     Kevin
# 5                                     Parni Valjak   Logged In     Kevin
# 6                                             None   Logged In     Kevin
# 7                                             Flaw   Logged In     Kevin
# 8                                     Foo Fighters   Logged In     Kevin
# 9                          ÃÂngeles del Infierno   Logged In     Kevin
# 10                                     Smash Mouth   Logged In     Kevin
# 11                                            None   Logged In      Ayla
# 12                          BeyoncÃÂ© feat. Jay-Z   Logged In      Ayla
# 13                                         Aaliyah   Logged In      Ayla
# 14                                            None   Logged In     Emily
# 15                                        Coldplay   Logged In     Emily
# 16                                  Martin Solveig   Logged In     Emily
# 17                                            None   Logged In     Emily
# 18                                            None  Logged Out      None
# 19                                            None  Logged Out      None
# 20                                            None  Logged Out      None
# 21                                            None   Logged In     Emily
# 22                                    Simple Minds   Logged In      Ryan
# 23                                   Guns N' Roses   Logged In      Ryan
# 24                                       Erin Bode   Logged In     Rylan
# 25                                Blue Oyster Cult   Logged In     Rylan
# 26                                    Little Boots   Logged In     Rylan
# 27                                       FM Static   Logged In     Rylan
# 28                                   Dead Kennedys   Logged In     Rylan
# 29   Jim Jones & Ron Browz featuring Juelz Santana   Logged In     Rylan
# ..                                             ...         ...       ...
# 269                               Michael W. Smith   Logged In   Kinsley
# 270                                    The Killers   Logged In   Kinsley
# 271                               Michael BublÃÂ©   Logged In   Kinsley
# 272                                       Harmonia   Logged In   Kinsley
# 273                                Bobby Goldsboro   Logged In   Kinsley
# 274                   Creedence Clearwater Revived   Logged In   Kinsley
# 275                          Ghostland Observatory   Logged In   Kinsley
# 276                                          Feist   Logged In     Aiden
# 277                                  Uncle Kracker   Logged In   Kinsley
# 278                                     Per Gessle   Logged In   Kinsley
# 279                                     Big & Rich   Logged In   Kinsley
# 280                                 Dead Can Dance   Logged In   Kinsley
# 281                                           None  Logged Out      None
# 282                                Alliance Ethnik   Logged In   Kinsley
# 283                             DAVE MATTHEWS BAND   Logged In   Kinsley
# 284                                           None   Logged In   Kinsley
# 285                                    Victor Jara   Logged In   Kinsley
# 286                                     Rose Royce   Logged In   Kinsley
# 287                                    Sex Pistols   Logged In   Kinsley
# 288                                 Devin Townsend   Logged In   Kinsley
# 289                                   Szarka Gyula   Logged In   Kinsley
# 290                                      The Clash   Logged In   Kinsley
# 291                                      DJ Shadow   Logged In   Kinsley
# 292                                           Beck   Logged In   Kinsley
# 293                                  Johnny Mathis   Logged In   Kinsley
# 294                                 Nicolai Dunger   Logged In   Kinsley
# 295                                           None   Logged In   Kinsley
# 296                                           None  Logged Out      None
# 297                                           None   Logged In    Kimber
# 298          Miranda Cosgrove featuring Drake Bell   Logged In    Kimber
#
#     gender  itemInSession  lastName     length level  \
# 0        M              0  Arellano  215.11791  free
# 1        M              1  Arellano  204.74730  free
# 2        M              2  Arellano  172.01587  free
# 3        M              3  Arellano  209.52771  free
# 4        M              4  Arellano  266.44853  free
# 5        M              5  Arellano  259.83955  free
# 6        M              6  Arellano        NaN  free
# 7        M              7  Arellano  265.89995  free
# 8        M              8  Arellano  250.14812  free
# 9        M              9  Arellano  267.25832  free
# 10       M             10  Arellano  216.39791  free
# 11       F              0   Johnson        NaN  free
# 12       F              1   Johnson  235.93751  free
# 13       F              2   Johnson  228.28363  free
# 14       F              0    Benson        NaN  paid
# 15       F              1    Benson  268.38159  paid
# 16       F              2    Benson  246.28200  paid
# 17       F              3    Benson        NaN  paid
# 18    None              4      None        NaN  paid
# 19    None              5      None        NaN  paid
# 20    None              6      None        NaN  paid
# 21       F              7    Benson        NaN  paid
# 22       M              0     Smith  240.03873  free
# 23       M              1     Smith  284.05506  free
# 24       M              0    George  252.05506  paid
# 25       M              1    George  322.42893  paid
# 26       M              2    George  195.94404  paid
# 27       M              3    George  218.27873  paid
# 28       M              4    George   90.40934  paid
# 29       M              5    George  215.97995  paid
# ..     ...            ...       ...        ...   ...
# 269      F              6     Young  254.79791  paid
# 270      F              7     Young  258.89914  paid
# 271      F              8     Young  184.94649  paid
# 272      F              9     Young  655.77751  paid
# 273      F             10     Young  238.60200  paid
# 274      F             11     Young  297.87383  paid
# 275      F             12     Young  301.13914  paid
# 276      M              0      Hess  184.94649  free
# 277      F             13     Young  216.08444  paid
# 278      F             14     Young  192.67873  paid
# 279      F             15     Young  298.23955  paid
# 280      F             16     Young  230.05995  paid
# 281   None              0      None        NaN  paid
# 282      F             17     Young  195.94404  paid
# 283      F             18     Young  109.50485  paid
# 284      F             19     Young        NaN  paid
# 285      F             20     Young  105.58649  paid
# 286      F             21     Young  275.95710  paid
# 287      F             22     Young  194.63791  paid
# 288      F             23     Young  436.40118  paid
# 289      F             24     Young  243.53914  paid
# 290      F             25     Young  186.06975  paid
# 291      F             26     Young  549.56363  paid
# 292      F             27     Young  139.59791  paid
# 293      F             28     Young  140.93016  paid
# 294      F             29     Young  163.65669  paid
# 295      F             30     Young        NaN  paid
# 296   None             31      None        NaN  paid
# 297      F              0    Norris        NaN  free
# 298      F              1    Norris  161.04444  free
#
#                                   location method       page  registration  \
# 0                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 1                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 2                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 3                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 4                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 5                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 6                  Harrisburg-Carlisle, PA    GET       Home  1.540007e+12
# 7                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 8                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 9                  Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 10                 Harrisburg-Carlisle, PA    PUT   NextSong  1.540007e+12
# 11                          Santa Rosa, CA    GET       Home  1.540880e+12
# 12                          Santa Rosa, CA    PUT   NextSong  1.540880e+12
# 13                          Santa Rosa, CA    PUT   NextSong  1.540880e+12
# 14          Augusta-Richmond County, GA-SC    GET       Home  1.540907e+12
# 15          Augusta-Richmond County, GA-SC    PUT   NextSong  1.540907e+12
# 16          Augusta-Richmond County, GA-SC    PUT   NextSong  1.540907e+12
# 17          Augusta-Richmond County, GA-SC    PUT     Logout  1.540907e+12
# 18                                    None    GET       Home           NaN
# 19                                    None    GET      About           NaN
# 20                                    None    PUT      Login           NaN
# 21          Augusta-Richmond County, GA-SC    GET       Home  1.540907e+12
# 22      San Jose-Sunnyvale-Santa Clara, CA    PUT   NextSong  1.541017e+12
# 23      San Jose-Sunnyvale-Santa Clara, CA    PUT   NextSong  1.541017e+12
# 24                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# 25                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# 26                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# 27                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# 28                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# 29                   Birmingham-Hoover, AL    PUT   NextSong  1.541020e+12
# ..                                     ...    ...        ...           ...
# 269                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 270                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 271                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 272                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 273                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 274                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 275                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 276              La Crosse-Onalaska, WI-MN    PUT   NextSong  1.540829e+12
# 277                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 278                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 279                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 280                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 281                                   None    GET       Home           NaN
# 282                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 283                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 284                          Red Bluff, CA    GET  Downgrade  1.540465e+12
# 285                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 286                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 287                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 288                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 289                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 290                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 291                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 292                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 293                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 294                          Red Bluff, CA    PUT   NextSong  1.540465e+12
# 295                          Red Bluff, CA    PUT     Logout  1.540465e+12
# 296                                   None    GET       Home           NaN
# 297  New York-Newark-Jersey City, NY-NJ-PA    GET       Home  1.540976e+12
# 298  New York-Newark-Jersey City, NY-NJ-PA    PUT   NextSong  1.540976e+12
#
#      sessionId                                         song  status  \
# 0          815                             Your Rocky Spine     200
# 1          815                                      Va Bien     200
# 2          815                    Eleanor Put Your Boots On     200
# 3          815                                     Float On     200
# 4          815                                    Aftermath     200
# 5          815                            Dok si pored mene     200
# 6          815                                         None     200
# 7          815                                   Not Enough     200
# 8          815                                     Everlong     200
# 9          815                 Si TÃÂº No EstÃÂ¡s AquÃÂ­     200
# 10         815                                     All Star     200
# 11         839                                         None     200
# 12         839                                Crazy In Love     200
# 13         839                            More Than A Woman     200
# 14         821                                         None     200
# 15         821                                       Yellow     200
# 16         821                          Something About You     200
# 17         821                                         None     307
# 18         821                                         None     200
# 19         821                                         None     200
# 20         821                                         None     307
# 21         821                                         None     200
# 22         845                             Glittering Prize     200
# 23         845                         Don't Cry (Original)     200
# 24         617                   Here_ There And Everywhere     200
# 25         617                                Buck's Boogie     200
# 26         617                                       Meddle     200
# 27         617                                      Tonight     200
# 28         617                             Terminal Preppie     200
# 29         617                                Pop Champagne     200
# ..         ...                                          ...     ...
# 269        891                                Draw Me Close     200
# 270        891                                       On Top     200
# 271        891     Some Kind Of Wonderful (Non-Album Track)     200
# 272        891                                Sehr kosmisch     200
# 273        891                                        Honey     200
# 274        891                                       Suzy Q     200
# 275        891                 Robotique Majestique (Album)     200
# 276        889                               My Moon My Man     200
# 277        891              Follow Me (Explicit LP Version)     200
# 278        891               Listen To Your Heart (Cologne)     200
# 279        891  8th Of November (Album Version) (w/o Intro)     200
# 280        891              The Writing On My Fathers Hand     200
# 281        882                                         None     200
# 282        891                     SinceritÃÂ© Et Jalousie     200
# 283        891                                          #40     200
# 284        891                                         None     200
# 285        891       Ay Mi Palomita (1997 Digital Remaster)     200
# 286        891                          Get Up Off Your Fat     200
# 287        891           Who Was It (Demo Version Of 'EMI')     200
# 288        891                                    The fluke     200
# 289        891                        BorivÃÂ³knak valÃÂ³     200
# 290        891                                 I'm Not Down     200
# 291        891                        Blood On The Motorway     200
# 292        891                                     Lemonade     200
# 293        891                                        Misty     200
# 294        891                                Our Filmscore     200
# 295        891                                         None     307
# 296        891                                         None     200
# 297        488                                         None     200
# 298        488       Leave It All To Me (Theme from iCarly)     200
#
#                 ts                                          userAgent userId
# 0    1542931645796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 1    1542931860796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 2    1542932064796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 3    1542932236796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 4    1542932445796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 5    1542932711796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 6    1542932752796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 7    1542932970796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 8    1542933235796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 9    1542933485796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 10   1542933752796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 11   1542933838796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     63
# 12   1542933907796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     63
# 13   1542934142796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     63
# 14   1542936763796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 15   1542936896796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 16   1542937164796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 17   1542937165796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 18   1542937172796                                               None
# 19   1542937234796                                               None
# 20   1542937235796                                               None
# 21   1542937294796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 22   1542940536796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 23   1542940776796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 24   1542944904796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 25   1542945156796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 26   1542945478796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 27   1542945673796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 28   1542945891796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 29   1542945981796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# ..             ...                                                ...    ...
# 269  1543003635796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 270  1543003889796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 271  1543004147796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 272  1543004331796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 273  1543004986796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 274  1543005224796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 275  1543005521796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 276  1543005627796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 277  1543005822796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 278  1543006038796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 279  1543006230796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 280  1543006528796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 281  1543006613796                                               None
# 282  1543006758796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 283  1543006953796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 284  1543006962796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 285  1543007062796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 286  1543007167796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 287  1543007442796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 288  1543007636796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 289  1543008072796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 290  1543008315796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 291  1543008501796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 292  1543009050796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 293  1543009189796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 294  1543009329796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 295  1543009330796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_...     85
# 296  1543009372796                                               None
# 297  1543014409796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     47
# 298  1543014528796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     47
#
# [299 rows x 18 columns]

# %%
all_songs = []

# %%
def get_all_song_titles_from_logs(log_files):
    song_titles = set()
    for file in log_files:
        with open(file, 'r') as f:
            for line in f:
                try:
                    d = json.loads(line)
                except JSONDecodeError as e:
                    print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
                    continue
                    
                if d['page'] == 'NextSong':
                    song_titles.add(d['song'])
    return list(song_titles)

# %%
all_songs_from_logs = get_all_song_titles_from_logs(log_files)

# %%
len(all_songs_from_logs)
# Out:
# 5189

# %%
def get_all_song_titles_from_songs(song_files):
    song_titles = set()
    for file in song_files:
        with open(file, 'r') as f:
            for line in f:
                try:
                    d = json.loads(line)
                except JSONDecodeError as e:
                    print('Msg: {e.msg}, Doc: {e.doc}, Pos: {e.pos}, LineNo: {e.lineno}, ColNo: {e.colno}')
                    continue
                song_titles.add(d['title'])
    return list(song_titles)

# %%
all_songs_from_songs = get_all_song_titles_from_songs(song_files)

# %%
len(all_songs_from_songs)
# Out:
# 71

# %%
df_songs.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  AR8ZCNI1187B9A069B              NaN                               NaN
#
#         artist_name   duration  num_songs             song_id       title  \
# 0  Planet P Project  269.81832          1  SOIAZJW12AB01853F1  Pink World
#
#    year
# 0  1984

# %%
name = "Elena"

# %%
title = "Setanta matins"

# %%
duration = 269.58322

# %%
"SELECT song_id, artist_id FROM songs WHERE title = '{}' and name = '{}' and duration = {}".format(title, name, duration)
# Out:
# "SELECT song_id, artist_id FROM songs WHERE title = 'Setanta matins' and artist_name = 'Elena' and duration = 269.58322"

# %%
qry = ("SELECT song_id, s.artist_id \
FROM songs s JOIN artists a on s.artist_id = a.artist_id \
WHERE title = '{}' and a.name='{}' and duration={}".format(title, name, duration))

# %%
qry
# Out:
# "SELECT song_id, s.artist_id FROM songs s JOIN artists a on s.artist_id = a.artist_id WHERE title = 'Setanta matins' and a.name='Elena' and duration=269.58322"

# %%
cur.execute(qry)

# %%
rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# ('SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4')

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
